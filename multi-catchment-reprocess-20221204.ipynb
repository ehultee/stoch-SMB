# %% [markdown]
# Re-run the multi-catchment processing scheme to aggregate data to catchment means.  TODO: load in new dEBM data and process calibration period and forward projections.

# %%
from shapely.geometry import MultiPoint
from shapely.ops import triangulate
import shapefile
from netCDF4 import Dataset
import numpy as np
import pandas as pd
import pyproj as pyproj
from scipy import interpolate
import datetime
import time

# %%
###------------------------
### DATA READ-IN  AND PROJECTION
###------------------------

## Read in BedMachine grid to reproject SMB
gl_bed_path ='/Users/lizz/Documents/GitHub/Data_unsynced/BedMachine-Greenland/BedMachineGreenland-2017-09-20.nc'
fh = Dataset(gl_bed_path, mode='r')
xx = fh.variables['x'][:].copy() #x-coord (polar stereo (70, 45))
yy = fh.variables['y'][:].copy() #y-coord
M = fh.variables['mask'][:].copy() ## land cover type mask (2 = grounded ice)
fh.close()

## Read in Mouginot catchments from shapefile
print('Reading in Mouginot catchments')
catchment_fn = '/Users/lizz/Documents/GitHub/Data_unsynced/Greenland-catchments-Mouginot/Greenland_Basins_PS_v1.4.2.'
sf = shapefile.Reader(catchment_fn) 

## Example SMB field read in for grid
print('Reading in example SMB field')
nhm_smb_path = '/Volumes/GoogleDrive/My Drive/SMBMIP/NHM-SMAP_niwano-monthly-ERA-Interim-1980.nc'
fh2 = Dataset(nhm_smb_path, mode='r')
xlon_nhm = fh2.variables['LON'][:].copy() #x-coord (latlon)
ylat_nhm = fh2.variables['LAT'][:].copy() #y-coord (latlon)
fh2.close()
# Out:
# Reading in Mouginot catchments
# Reading in example SMB field

# %%
###------------------------
### SET UP SMB REPROJECTION
###------------------------

## Down-sample bed topo
x_3km = xx[::20] # sample at ~3 km resolution
y_3km = yy[::20]
Xmat, Ymat = np.meshgrid(x_3km, y_3km) # Downsampled BedMachine coords

## Down-sample SMB
x_lon_h = xlon_nhm[::2, ::2] 
y_lat_h = ylat_nhm[::2, ::2] # resolution about 2 km

print('Creating reprojected grid')
wgs84 = pyproj.Proj("+init=EPSG:4326") # LatLon with WGS84 datum used by SMB data
psn_gl = pyproj.Proj("+init=epsg:3413") # Polar Stereographic North used by BedMachine and Mankoff
xs, ys = pyproj.transform(wgs84, psn_gl, x_lon_h, y_lat_h)
# Out:
# Creating reprojected grid
# /opt/anaconda3/envs/stisp/lib/python3.7/site-packages/pyproj/crs/crs.py:280: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(projparams)
# /opt/anaconda3/envs/stisp/lib/python3.7/site-packages/pyproj/crs/crs.py:280: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(projparams)
# /opt/anaconda3/envs/stisp/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1

# %%
###------------------------
### CHOOSE CATCHMENTS
###------------------------
catchments_to_pull = np.arange(70, 120)

# %%
###------------------------
### CREATE FRAMEWORK
###------------------------

## Perform Delaunay triangulation over each catchment region
tri_ctmts = {i: [] for i in catchments_to_pull}
for i in catchments_to_pull:
    print('Triangulating catchment {}'.format(sf.record(i)['NAME']))
    c = MultiPoint(sf.shape(i).points)
    tris = triangulate(c)
    tri_ctmts[i] = tris

## Create data frames to store per-model time series
model_names = ['ANICE-ITM_Berends', 'CESM_kampenhout', 'dEBM_krebs','HIRHAM_mottram', 
                'NHM-SMAP_niwano', 'RACMO_noel', 'SNOWMODEL_liston']
# model_names = ['ANICE-ITM_Berends',]
years = range(1980,2013)
start_date = datetime.datetime(years[0],1,1)
end_date = datetime.datetime(years[-1],12,31)
dates = pd.date_range(start=start_date, end=end_date, freq='M')
df_per_ctchmnt = {i: pd.DataFrame(columns=model_names, index=dates) for i in catchments_to_pull}
# Out:
# Triangulating catchment ISUNNGUATA-RUSSELL
# Triangulating catchment EQIP_SERMIA
# Triangulating catchment SE_NONAME2
# Triangulating catchment KONG_CHRISTIAN
# Triangulating catchment SORGENFRI
# Triangulating catchment VESTFJORD
# Triangulating catchment JUNGERSEN_HENSON_NARAVANA
# Triangulating catchment DOCKER_SMITH_GLETSCHER
# Triangulating catchment SE_NONAME4
# Triangulating catchment TINGMIARMIUT_FJORD
# Triangulating catchment SERMEQ_KUJALLEQ
# Triangulating catchment KANGILERNGATA_SERMIA
# Triangulating catchment GRAULV
# Triangulating catchment OSTENFELD_GLETSCHER
# Triangulating catchment KANGERLUARSUUP_SERMIA
# Triangulating catchment UPERNAVIK_ISSTROM_N
# Triangulating catchment WORDIE-VIBEKE
# Triangulating catchment SE_NONAME1
# Triangulating catchment SE_NONAME5
# Triangulating catchment SE_NONAME6
# Triangulating catchment SE_NONAME7
# Triangulating catchment SE_NONAME8
# Triangulating catchment FENRISGLETSCHER
# Triangulating catchment MIDGARDGLETSCHER
# Triangulating catchment UNNAMED_DECEPTION_O_CN_CS
# Triangulating catchment KIV_STEENSTRUP_NODRE_BRAE
# Triangulating catchment UNNAMED_KANGER_E
# Triangulating catchment MAGGA_DAN_GLETSCHER
# Triangulating catchment GEIKIE1
# Triangulating catchment FREDERIKSBORG_GLETSCHER
# Triangulating catchment UNNAMED_SORGENFRI_W
# Triangulating catchment KANGERLUSSUAQ
# Triangulating catchment FARQUHAR_GLETSCHER
# Triangulating catchment MELVILLE_GLETSCHER
# Triangulating catchment SHARP
# Triangulating catchment KOGE_BUGT_C
# Triangulating catchment PUISORTOQ_N
# Triangulating catchment MOGENS_HEINESEN_SS_SSS
# Triangulating catchment HARDER_GLETSCHER
# Triangulating catchment UNNAMED_SOUTH_DANELL_FJORD
# Triangulating catchment SOUTHERN_TIP
# Triangulating catchment HERLUF_TROLLE-KANGERLULUK-DANELL
# Triangulating catchment UNNAMED_KANGERLULUK
# Triangulating catchment UNNAMED_HERLUF_TROLLE_S
# Triangulating catchment UNNAMED_HERLUF_TROLLE_N
# Triangulating catchment UNNAMED_ANORITUUP_KANGERLUA_SS
# Triangulating catchment ANORITUUP_KANGERLUA
# Triangulating catchment UNNAMED_ANORITUUP_KANGERLUA_S
# Triangulating catchment SE_NONAME9
# Triangulating catchment UNNAMED_DANELL_FJORD

# %%
###------------------------
### CATCHMENT-SUM FOR ALL MODELS
###------------------------

for m in model_names:
    t0 = time.time()
    if m=='CESM_kampenhout':
        vname = 'SMBCORR'
    else:
        vname = 'SMBcorr'
    for y in years:
        ti = time.time()
        fpath = '/Volumes/GoogleDrive/My Drive/SMBMIP/{}-monthly-ERA-Interim-{}.nc'.format(m, y)
        fh = Dataset(fpath, mode='r')
        smb_m = fh.variables[vname][:].copy()
        fh.close()
        d_subset = [d for d in dates if d.year==y]
        for i in range(len(smb_m)): # for each month
            ## downsample and interpolate SMB
            smb_ds = smb_m[i][::2, ::2]
            regridded_smb = interpolate.griddata((xs.ravel(), ys.ravel()), smb_ds.ravel(), (Xmat, Ymat), method='nearest')
            ## Sample SMB at each Delaunay triangle and sum
            for j in catchments_to_pull:
                catchment_sum = 0
                area_sum = 0
                triangles = tri_ctmts[j]
                for tri in triangles:
                    rep_x, rep_y = tri.representative_point().x, tri.representative_point().y
                    area_m2 = tri.area
                    smb_x = (np.abs(x_3km - rep_x)).argmin()
                    smb_y = (np.abs(y_3km - rep_y)).argmin()
                    nearest_smb = regridded_smb[smb_y, smb_x]
                    if nearest_smb < -6000: ## catch fill values or unrealistic extreme values
                        next_smb_x = np.argsort(np.abs(x_3km-rep_x))[1]
                        next_smb_y = np.argsort(np.abs(y_3km-rep_y))[1]
                        next_nearest_smb = regridded_smb[next_smb_y, next_smb_x]
                        ### TODO: add an option for a fill value, if next nearest is also bad?
                        local_val = next_nearest_smb*area_m2
                    elif nearest_smb > 6000: ## HIRHAM and SNOWMODEL have positive fill val
                        next_smb_x = np.argsort(np.abs(x_3km-rep_x))[1]
                        next_smb_y = np.argsort(np.abs(y_3km-rep_y))[1]
                        next_nearest_smb = regridded_smb[next_smb_y, next_smb_x]
                        ### TODO: add an option for a fill value, if next nearest is also bad?
                        local_val = next_nearest_smb*area_m2
                    else:
                        local_val = nearest_smb*area_m2
                    catchment_sum += local_val
                    area_sum += area_m2
                df_per_ctchmnt[j][m][d_subset[i]] = catchment_sum/area_sum
        tf = time.time()
        print('Finished processing year {} in time {}s'.format(y, tf-ti))
    t1 = time.time()
    print('Finished processing model {} in time {}'.format(m, t1-t0))

## Write to CSV
for i in catchments_to_pull:  
    csv_ctchmnt = '/Users/lizz/Documents/GitHub/Data_unsynced/SMBMIP-processed/{}-catchment_{}_mean-tseries.csv'.format(datetime.date.today().strftime('%Y%m%d'), i)
    df_per_ctchmnt[i].to_csv(csv_ctchmnt)
# Out:
# Finished processing year 1980 in time 54.111258029937744s
# Finished processing year 1981 in time 52.61349606513977s
# Finished processing year 1982 in time 52.709951877593994s
# Finished processing year 1983 in time 52.91398501396179s
# Finished processing year 1984 in time 52.43429708480835s
# Finished processing year 1985 in time 52.5105459690094s
# Finished processing year 1986 in time 52.71483397483826s
# Finished processing year 1987 in time 52.600178956985474s
# Finished processing year 1988 in time 53.15723180770874s
# Finished processing year 1989 in time 52.543217182159424s
# Finished processing year 1990 in time 52.61350131034851s
# Finished processing year 1991 in time 52.84213972091675s
# Finished processing year 1992 in time 52.88209271430969s
# Finished processing year 1993 in time 52.91222095489502s
# Finished processing year 1994 in time 53.41806697845459s
# Finished processing year 1995 in time 52.87094593048096s
# Finished processing year 1996 in time 53.040261030197144s
# Finished processing year 1997 in time 53.35634899139404s
# Finished processing year 1998 in time 53.03156399726868s
# Finished processing year 1999 in time 53.09574818611145s
# Finished processing year 2000 in time 53.15893292427063s
# Finished processing year 2001 in time 53.36235523223877s
# Finished processing year 2002 in time 53.189663887023926s
# Finished processing year 2003 in time 53.23506283760071s
# Finished processing year 2004 in time 53.1570680141449s
# Finished processing year 2005 in time 53.045846939086914s
# Finished processing year 2006 in time 53.41702127456665s
# Finished processing year 2007 in time 53.16723990440369s
# Finished processing year 2008 in time 53.223389863967896s
# Finished processing year 2009 in time 53.50456190109253s
# Finished processing year 2010 in time 53.067527770996094s
# Finished processing year 2011 in time 53.59274411201477s
# Finished processing year 2012 in time 53.1566846370697s
# Finished processing model ANICE-ITM_Berends in time 1750.6537499427795
# Finished processing year 1980 in time 57.9091420173645s
# Finished processing year 1981 in time 57.79567098617554s
# Finished processing year 1982 in time 58.00857973098755s
# Finished processing year 1983 in time 57.64986610412598s
# Finished processing year 1984 in time 57.624309062957764s
# Finished processing year 1985 in time 58.02893114089966s
# Finished processing year 1986 in time 60.69766807556152s
# Finished processing year 1987 in time 57.57711172103882s
# Finished processing year 1988 in time 57.75002980232239s
# Finished processing year 1989 in time 57.573960065841675s
# Finished processing year 1990 in time 57.77653098106384s
# Finished processing year 1991 in time 57.831578969955444s
# Finished processing year 1992 in time 57.847540855407715s
# Finished processing year 1993 in time 58.37300109863281s
# Finished processing year 1994 in time 58.70863175392151s
# Finished processing year 1995 in time 58.025835037231445s
# Finished processing year 1996 in time 59.03675699234009s
# Finished processing year 1997 in time 57.89887309074402s
# Finished processing year 1998 in time 57.7337007522583s
# Finished processing year 1999 in time 59.96443223953247s
# Finished processing year 2000 in time 57.68185997009277s
# Finished processing year 2001 in time 57.730116844177246s
# Finished processing year 2002 in time 57.744166135787964s
# Finished processing year 2003 in time 57.81260704994202s
# Finished processing year 2004 in time 57.83519887924194s
# Finished processing year 2005 in time 58.48941373825073s
# Finished processing year 2006 in time 57.57364797592163s
# Finished processing year 2007 in time 57.77495884895325s
# Finished processing year 2008 in time 57.903112173080444s
# Finished processing year 2009 in time 57.797565937042236s
# Finished processing year 2010 in time 57.75512409210205s
# Finished processing year 2011 in time 57.697153091430664s
# Finished processing year 2012 in time 57.95388102531433s
# Finished processing model CESM_kampenhout in time 1915.5726718902588
# Finished processing year 1980 in time 53.37865495681763s
# Finished processing year 1981 in time 53.35277581214905s
# Finished processing year 1982 in time 53.16315007209778s
# Finished processing year 1983 in time 54.90354800224304s
# Finished processing year 1984 in time 55.79307770729065s
# Finished processing year 1985 in time 53.13974118232727s
# Finished processing year 1986 in time 53.34387516975403s
# Finished processing year 1987 in time 53.26762080192566s
# Finished processing year 1988 in time 56.21167492866516s
# Finished processing year 1989 in time 54.74663710594177s
# Finished processing year 1990 in time 55.48193025588989s
# Finished processing year 1991 in time 53.01050591468811s
# Finished processing year 1992 in time 53.10172891616821s
# Finished processing year 1993 in time 56.13465213775635s
# Finished processing year 1994 in time 52.998648166656494s
# Finished processing year 1995 in time 55.632786989212036s
# Finished processing year 1996 in time 53.16820287704468s
# Finished processing year 1997 in time 53.088967084884644s
# Finished processing year 1998 in time 53.074294090270996s
# Finished processing year 1999 in time 53.04298186302185s
# Finished processing year 2000 in time 53.09115958213806s
# Finished processing year 2001 in time 55.452229738235474s
# Finished processing year 2002 in time 53.05191683769226s
# Finished processing year 2003 in time 53.238441944122314s
# Finished processing year 2004 in time 53.13563418388367s
# Finished processing year 2005 in time 53.18026280403137s
# Finished processing year 2006 in time 52.986644983291626s
# Finished processing year 2007 in time 54.65542793273926s
# Finished processing year 2008 in time 55.73647594451904s
# Finished processing year 2009 in time 53.10628700256348s
# Finished processing year 2010 in time 53.08288502693176s
# Finished processing year 2011 in time 53.069082260131836s
# Finished processing year 2012 in time 52.9916250705719s
# Finished processing model dEBM_krebs in time 1776.8175971508026
# Finished processing year 1980 in time 56.73927187919617s
# Finished processing year 1981 in time 56.34112095832825s
# Finished processing year 1982 in time 56.49391293525696s
# Finished processing year 1983 in time 53.82742619514465s
# Finished processing year 1984 in time 54.164429664611816s
# Finished processing year 1985 in time 53.86517810821533s
# Finished processing year 1986 in time 53.84620428085327s
# Finished processing year 1987 in time 53.82948303222656s
# Finished processing year 1988 in time 53.85726523399353s
# Finished processing year 1989 in time 56.13134407997131s
# Finished processing year 1990 in time 53.94110894203186s
# Finished processing year 1991 in time 53.90740203857422s
# Finished processing year 1992 in time 53.995635986328125s
# Finished processing year 1993 in time 53.945444107055664s
# Finished processing year 1994 in time 54.04996585845947s
# Finished processing year 1995 in time 53.98445534706116s
# Finished processing year 1996 in time 56.642382860183716s
# Finished processing year 1997 in time 53.94453406333923s
# Finished processing year 1998 in time 54.05608415603638s
# Finished processing year 1999 in time 54.0402250289917s
# Finished processing year 2000 in time 53.777820348739624s
# Finished processing year 2001 in time 53.93749809265137s
# Finished processing year 2002 in time 56.65560865402222s
# Finished processing year 2003 in time 53.87739419937134s
# Finished processing year 2004 in time 53.869469165802s
# Finished processing year 2005 in time 54.012030839920044s
# Finished processing year 2006 in time 56.23093295097351s
# Finished processing year 2007 in time 54.02880787849426s
# Finished processing year 2008 in time 55.08021306991577s
# Finished processing year 2009 in time 54.14949989318848s
# Finished processing year 2010 in time 54.007779121398926s
# Finished processing year 2011 in time 56.66653108596802s
# Finished processing year 2012 in time 55.89291286468506s
# Finished processing model HIRHAM_mottram in time 1803.793552160263
# Finished processing year 1980 in time 53.332221031188965s
# Finished processing year 1981 in time 56.301347732543945s
# Finished processing year 1982 in time 56.194833755493164s
# Finished processing year 1983 in time 53.446425914764404s
# Finished processing year 1984 in time 53.32217979431152s
# Finished processing year 1985 in time 55.76607704162598s
# Finished processing year 1986 in time 53.27178502082825s
# Finished processing year 1987 in time 55.893012046813965s
# Finished processing year 1988 in time 53.089412212371826s
# Finished processing year 1989 in time 55.63105893135071s
# Finished processing year 1990 in time 53.24275183677673s
# Finished processing year 1991 in time 53.362231969833374s
# Finished processing year 1992 in time 53.50005578994751s
# Finished processing year 1993 in time 56.05570077896118s
# Finished processing year 1994 in time 59.66643929481506s
# Finished processing year 1995 in time 55.86535382270813s
# Finished processing year 1996 in time 55.72551703453064s
# Finished processing year 1997 in time 55.70199680328369s
# Finished processing year 1998 in time 53.34928607940674s
# Finished processing year 1999 in time 53.159503698349s
# Finished processing year 2000 in time 55.69919013977051s
# Finished processing year 2001 in time 56.03629422187805s
# Finished processing year 2002 in time 53.508461236953735s
# Finished processing year 2003 in time 57.17532682418823s
# Finished processing year 2004 in time 55.83013105392456s
# Finished processing year 2005 in time 53.31811809539795s
# Finished processing year 2006 in time 55.75878691673279s
# Finished processing year 2007 in time 55.62274408340454s
# Finished processing year 2008 in time 55.64301323890686s
# Finished processing year 2009 in time 55.546061754226685s
# Finished processing year 2010 in time 53.18688988685608s
# Finished processing year 2011 in time 56.12823820114136s
# Finished processing year 2012 in time 55.5896897315979s
# Finished processing model NHM-SMAP_niwano in time 1814.923388004303
# Finished processing year 1980 in time 56.02902889251709s
# Finished processing year 1981 in time 55.48567795753479s
# Finished processing year 1982 in time 55.86785697937012s
# Finished processing year 1983 in time 55.68606686592102s
# Finished processing year 1984 in time 55.56350898742676s
# Finished processing year 1985 in time 55.62572884559631s
# Finished processing year 1986 in time 55.83459424972534s
# Finished processing year 1987 in time 55.559836864471436s
# Finished processing year 1988 in time 55.800047874450684s
# Finished processing year 1989 in time 55.27437710762024s
# Finished processing year 1990 in time 55.49794006347656s
# Finished processing year 1991 in time 55.69855737686157s
# Finished processing year 1992 in time 55.309879779815674s
# Finished processing year 1993 in time 55.35292387008667s
# Finished processing year 1994 in time 55.563990116119385s
# Finished processing year 1995 in time 55.95524501800537s
# Finished processing year 1996 in time 55.4240038394928s
# Finished processing year 1997 in time 55.81252694129944s
# Finished processing year 1998 in time 55.705127239227295s
# Finished processing year 1999 in time 55.3538498878479s
# Finished processing year 2000 in time 55.69451904296875s
# Finished processing year 2001 in time 56.11961507797241s
# Finished processing year 2002 in time 55.41840696334839s
# Finished processing year 2003 in time 55.93136382102966s
# Finished processing year 2004 in time 55.56242299079895s
# Finished processing year 2005 in time 55.98286294937134s
# Finished processing year 2006 in time 56.06748390197754s
# Finished processing year 2007 in time 65.62758016586304s
# Finished processing year 2008 in time 54.886656045913696s
# Finished processing year 2009 in time 55.7838499546051s
# Finished processing year 2010 in time 55.676719188690186s
# Finished processing year 2011 in time 55.89694690704346s
# Finished processing year 2012 in time 55.650700092315674s
# Finished processing model RACMO_noel in time 1846.7047469615936
# Finished processing year 1980 in time 57.42087411880493s
# Finished processing year 1981 in time 57.38948607444763s
# Finished processing year 1982 in time 57.397692918777466s
# Finished processing year 1983 in time 58.13121795654297s
# Finished processing year 1984 in time 57.07959485054016s
# Finished processing year 1985 in time 57.573458194732666s
# Finished processing year 1986 in time 57.43250513076782s
# Finished processing year 1987 in time 56.84468674659729s
# Finished processing year 1988 in time 57.71114230155945s
# Finished processing year 1989 in time 57.514670848846436s
# Finished processing year 1990 in time 57.20212388038635s
# Finished processing year 1991 in time 57.27971816062927s
# Finished processing year 1992 in time 57.247031927108765s
# Finished processing year 1993 in time 57.45073175430298s
# Finished processing year 1994 in time 57.204386949539185s
# Finished processing year 1995 in time 56.99547791481018s
# Finished processing year 1996 in time 57.091917991638184s
# Finished processing year 1997 in time 57.874722957611084s
# Finished processing year 1998 in time 57.28807497024536s
# Finished processing year 1999 in time 56.922364950180054s
# Finished processing year 2000 in time 57.490041732788086s
# Finished processing year 2001 in time 57.32018423080444s
# Finished processing year 2002 in time 57.388970136642456s
# Finished processing year 2003 in time 57.44092297554016s
# Finished processing year 2004 in time 57.42011284828186s
# Finished processing year 2005 in time 57.2829110622406s
# Finished processing year 2006 in time 57.34964203834534s
# Finished processing year 2007 in time 57.2059531211853s
# Finished processing year 2008 in time 57.5423150062561s
# Finished processing year 2009 in time 57.18948197364807s
# Finished processing year 2010 in time 57.229655027389526s
# Finished processing year 2011 in time 58.03939604759216s
# Finished processing year 2012 in time 57.64279127120972s
# Finished processing model SNOWMODEL_liston in time 1893.5972740650177

# %% [markdown]
# ##
